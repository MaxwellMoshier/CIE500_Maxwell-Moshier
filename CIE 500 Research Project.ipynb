# %%
import numpy as np
import pandas as pd 

# sklearn
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# #Still Need to Download Datasets. Save Datasets into Jupyter notebook app
# Population data = pandas.read_csv('data.csv') #Make sure to replace data.csv
# Land use data =  pandas.read_csv('data.csv') #Make sure to replace data.csv
